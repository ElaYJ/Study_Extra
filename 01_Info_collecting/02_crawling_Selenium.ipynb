# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

chrome_driver = "../chromedriver-win64/chromedriver.exe"
service = Service(executable_path=chrome_driver)
options = webdriver.ChromeOptions()
browser = webdriver.Chrome(service=service, options=options)
browser.get("https://www.naver.com")

browser.set_window_position(x=3268, y=235)
browser.set_window_size(width=1000, height=1080)

# %%
# browser.back()
# browser.forward()
# browser.refresh()
browser.current_url
# Out:
# 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%EC%9E%90%EB%8F%99%ED%99%94'

# %% [markdown]
# #### 검색어 입력
#
# - 요소를 하나씩 클릭하는 방법

# %%
from selenium.webdriver.common.by import By

browser.find_element(By.ID, 'query').click()

# %%
browser.find_element(By.ID, 'query').send_keys("자동화")

# %%
browser.find_element(By.CLASS_NAME, 'btn_search').click()

# %% [markdown]
# - Keys 라이브러리를 사용하는 방법
#
# - Keys에 사용할 수 있는 버튼들...
#
# 	https://www.geeksforgeeks.org/special-keys-in-selenium-python/

# %%
from selenium.webdriver.common.keys import Keys

elem = browser.find_element(By.ID, 'query')
elem.send_keys("자동화")
elem.send_keys(Keys.ENTER)

# %% [markdown]
# #### 속성값 추출

# %%
b = browser.find_element(By.XPATH, '//*[@id="power_link_body"]/ul/li[1]/div/div[1]/a')
b
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="42c55fc6a5aa4f02d1bfa06ca189ae04", element="f.92A7E88CD37C27A56CE7B997B0A74B3A.d.C498F8335E5453B0ED52CE9396BA6EBB.e.22286")>

# %%
b = browser.find_element(By.XPATH, '//*[@id="power_link_body"]/ul/li[1]/div/div[1]/a').get_attribute('href')
b
# Out:
# 'https://adcr.naver.com/adcr?x=5SSgMF5FZyIifTAIJDvIU////w==...&p=0'

# %%
browser.quit()
